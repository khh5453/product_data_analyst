# %% [markdown]
# ### 사각형 넓이 구하기

# %%
class Square:
    def __init__(self):  # 생성자__init__의 매개변수의 첫번째는 self여야 합니다. 
        self.square = int(input('넓이를 구하고 싶은 사각형의 숫자를 써주세요.\n 1.직사각형 2.평행사변형 3.사다리꼴 \n >>>'))  # 입력값을 int로 묶어야 합니다.

        if self.square == 1:
            print('직사각형 함수는 rect()입니다.')  # Square 클래스에 rect() 메서드를 추가합니다. 

        elif self.square == 2:
            print('평행사변형 함수는 par()입니다.')  # Square 클래스에 par() 메서드를 추가합니다.  
        
        elif self.square == 3:
            print('사다리꼴 함수는 trape()입니다.')  # Square 클래스에 trape() 메서드를 추가합니다. 
        
        else:
            print('1, 2, 3 중에서 다시 입력해주세요')
            
    # 직사각형 메서드
    def rect(self):
        width, vertical = map(int, input('가로, 세로를 입력하세요. 예시 : 가로,세로\n >>>').strip().split(','))
        area = width * vertical
        result = '직사각형의 넓이는 : ' + str(area)
        return result
    
    # 평행사변형 메서드
    def par(self):
        base, height = map(int, input('밑변, 높이를 입력하세요. 예시 : 가로,세로\n >>>').strip().split(','))
        area = base * height
        result = f'평행사변형의 넓이는 : {area}'
        return result

    # 사다리꼴 메서드
    def trape(self):
        base, upper, height = map(int, input('밑변, 윗변, 높이를 입력하세요. 예시 : 밑변,윗변,높이\n >>>').strip().split(','))
        area = (base + upper) * height * 0.5
        result = f'(등변) 사다리꼴의 넓이는 : {area}'
        return result

# %%
a = Square()  # 객체 생성 & 2, 3을 각각 입력해 봅시다.
# Out:
# 넓이를 구하고 싶은 사각형의 숫자를 써주세요.
#  1.직사각형 2.평행사변형 3.사다리꼴
#  >>>1
# 직사각형 함수는 rect()입니다.

# %%
# 직사각형의 넓이
a.rect()  # 3, 5를 입력했을 때 넓이가 15가 나와야 합니다.
# Out:
# 가로, 세로를 입력하세요. 예시 : 가로,세로
#  >>>3,5
# '직사각형의 넓이는 : 15'

# %%
# 평형사변형의 넓이
a.par()  # 3,2를 입력했을 때 넓이가 6이 나와야 합니다.
# Out:
# 밑변, 높이를 입력하세요. 예시 : 가로,세로
#  >>>3,2
# '평행사변형의 넓이는 : 6'

# %%
# 사다리꼴의 넓이
a.trape()  # 3,2,1 을 입력했을 때 넓이가 2.5이 나와야 합니다.
# Out:
# 밑변, 윗변, 높이를 입력하세요. 예시 : 밑변,윗변,높이
#  >>>3,2,1
# '(등변) 사다리꼴의 넓이는 : 2.5'

# %% [markdown]
# ### 음료 주문 키오스크 만들기 1

# %%
# 문제 2-4. 추가 주문       
# 추가 음료의 온도를 입력받고, 가격 리스트와 주문 리스트, 합계 금액을 업데이트합니다. 

class Kiosk: 
    def __init__(self):
        # 문제 2-1의 답을 입력하세요. 
        self.menu = ['americano', 'latte', 'mocha', 'yuza_tea', 'green_tea', 'choco_latte']
        self.price = [2000, 3000, 3000, 2500, 2500, 3000]

    # 메뉴 출력 메서드
    def menu_print(self):
        for i in range(len(self.menu)):
            print(i + 1, self.menu[i], ' : ', self.price[i], '원')
        print()

    def menu_select(self):
        self.order_menu = []  # 주문 리스트
        self.order_price = []  # 가격 리스트

        n = 0
        while n < 1 or len(self.menu) < n:
            n = int(input("음료를 번호를 입력하세요 : "))  # 음료 번호 입력

            # 메뉴판에 있는 음료 번호일 때
            if 1 <= n & n <= len(self.menu):
                self.order_price.append(self.price[n-1])  # 가격 리스트에 추가합니다.
                self.price_sum = self.price[n-1]  # 합계 금액

                # 메뉴판에 없는 번호일 때
            else:  
                print("없는 메뉴입니다. 다시 주문해 주세요.")


        # 음료 온도 물어보기
        t = 0  # 기본값을 넣어주고
        while t != 1 and t != 2:  # 1이나 2를 입력할 때까지 물어보기
            t= int(input("HOT 음료는 1을, ICE 음료는 2를 입력하세요 : "))
            # 문제 2-3의 답을 입력하세요. 
            if t == 1:
                self.temp = 'HOT'
            elif t == 2:
                self.temp = 'ICE'

            else:    
                print("1과 2 중 하나를 입력하세요.\n")

        self.order_menu.append(self.temp + ' ' + self.menu[n-1])  # 주문 리스트에 추가합니다.
        # 문제 2-2의 답을 입력하세요. 
        print(self.temp, self.menu[n-1], ' : ', self.price_sum, '원')  # 온도 속성을 추가한 주문 결과를 출력합니다.

        # 추가 주문 또는 지불
        while n != 0:  # 지불을 선택하기 전까지 반복합니다.
            print()  # 줄 바꾸면서 
            n = int(input("추가 주문은 음료 번호를, 지불은 0을 누르세요 : "))  # 추가 주문 또는 지불
            if n > 0 and n < len(self.menu) + 1: 
                self.order_price.append(self.price[n-1])  # 가격 리스트에 추가합니다.
                self.price_sum += self.price[n-1]  # 합계 금액

                # 추가 음료 온도 
                # 문제 2-4. 추가 음료의 온도를 입력받고, 가격 리스트, 주문 리스트, 합계 금액을 업데이트해보세요.
                t = 0
                while t != 1 and t != 2:
                    t = int(input("HOT 음료는 1을, ICE 음료는 2를 입력하세요 : "))
                    if t == 1:
                        self.temp = "HOT"
                    elif t == 2:
                        self.temp = 'ICE'
                    else :
                        print("1과 2 중 하나를 입력하세요. \n")
                self.order_menu.append(self.temp + ' ' + self.menu[n-1])

                print('추가 주문 음료', self.temp, self.menu[n-1], ':', self.price[n-1], '원\n', '합계 : ', self.price_sum, '원')
            else :
                if n == 0 :  # 지불을 입력하면
                    print("주문이 완료되었습니다.")
                    print(self.order_menu, self.order_price)  # 확인을 위한 리스트를 출력합니다.
                else :  # 없는 번호를 입력할 때
                    print("없는 메뉴입니다. 다시 주문해 주세요.")

# %%
# 5가지 이상의 음료를 주문하고 리스트 확인하기 
a = Kiosk()  # 객체 생성
a.menu_print()  # 메뉴 출력
a.menu_select()  # 주문
# Out:
# 1 americano  :  2000 원
# 2 latte  :  3000 원
# 3 mocha  :  3000 원
# 4 yuza_tea  :  2500 원
# 5 green_tea  :  2500 원
# 6 choco_latte  :  3000 원
#
# 음료를 번호를 입력하세요 : 1
# HOT 음료는 1을, ICE 음료는 2를 입력하세요 : 2
# ICE americano  :  2000 원
#
# 추가 주문은 음료 번호를, 지불은 0을 누르세요 : 2
# HOT 음료는 1을, ICE 음료는 2를 입력하세요 : 2
# 추가 주문 음료 ICE latte : 3000 원
#  합계 :  5000 원
#
# 추가 주문은 음료 번호를, 지불은 0을 누르세요 : 0
# 주문이 완료되었습니다.
# ['ICE americano', 'ICE latte'] [2000, 3000]

# %% [markdown]
# ### 키오스크 만들기 2

# %%
# 문제 3-3. 클래스 업데이트  
# 앞에서 구현했던 메서드들을 Kiosk 클래스에 추가합니다. 직접 코드를 작성해 보세요! 

class Kiosk:
    def __init__(self):
        self.menu = ['americano', 'latte', 'mocha', 'yuza_tea', 'green_tea', 'choco_latte']
        self.price = [2000, 3000, 3000, 2500, 2500, 3000]

    # 메뉴 출력 메서드
    def menu_print(self):
        for i in range(len(self.menu)):
            print(i + 1, self.menu[i], ' : ', self.price[i], '원')
        print()

    # 주문 메서드
    def menu_select(self):
        self.order_menu = []  # 주문 리스트
        self.order_price = []  # 가격 리스트

        n = 0
        while n < 1 or len(self.menu) < n:
            n = int(input("음료를 번호를 입력하세요 : "))  # 음료 번호 입력

            # 메뉴판에 있는 음료 번호일 때
            if 1 <= n & n <= len(self.menu):
                self.order_price.append(self.price[n-1])  # 가격 리스트에 추가합니다.
                self.price_sum = self.price[n-1]  # 합계 금액

                # 메뉴판에 없는 번호일 때
            else:  
                print("없는 메뉴입니다. 다시 주문해 주세요.")


        # 음료 온도 물어보기
        t = 0  # 기본값을 넣어주고
        while t != 1 and t != 2:  # 1이나 2를 입력할 때까지 물어보기
            t= int(input("HOT 음료는 1을, ICE 음료는 2를 입력하세요 : "))
            # 문제 2-3의 답을 입력하세요. 
            if t == 1:
                self.temp = 'HOT'
            elif t == 2:
                self.temp = 'ICE'

            else:    
                print("1과 2 중 하나를 입력하세요.\n")

        self.order_menu.append(self.temp + ' ' + self.menu[n-1])  # 주문 리스트에 추가합니다.
        # 문제 2-2의 답을 입력하세요. 
        print(self.temp, self.menu[n-1], ' : ', self.price_sum, '원')  # 온도 속성을 추가한 주문 결과를 출력합니다.

        # 추가 주문 또는 지불
        while n != 0:  # 지불을 선택하기 전까지 반복합니다.
            print()  # 줄 바꾸면서 
            n = int(input("추가 주문은 음료 번호를, 지불은 0을 누르세요 : "))  # 추가 주문 또는 지불
            if n > 0 and n < len(self.menu) + 1: 
                # 추가 음료 온도 
                # 문제 2-4. 추가 음료의 온도를 입력받고, 가격 리스트, 주문 리스트, 합계 금액을 업데이트해보세요.
                t = 0
                while t != 1 and t != 2:
                    t = int(input("HOT 음료는 1을, ICE 음료는 2를 입력하세요 : "))
                    if t == 1:
                        self.temp = "HOT"
                    elif t == 2:
                        self.temp = 'ICE'
                    else :
                        print("1과 2 중 하나를 입력하세요. \n")
                        
                self.order_price.append(self.price[n-1])  # 가격 리스트에 추가합니다.
                self.price_sum += self.price[n-1]  # 합계 금액
                self.order_menu.append(self.temp + ' ' + self.menu[n-1])

                print('추가 주문 음료', self.temp, self.menu[n-1], ':', self.price[n-1], '원\n', '합계 : ', self.price_sum, '원')
            else :
                if n == 0 :  # 지불을 입력하면
                    print("주문이 완료되었습니다.")
                    print(self.order_menu, self.order_price)  # 확인을 위한 리스트를 출력합니다.
                else :  # 없는 번호를 입력할 때
                    print("없는 메뉴입니다. 다시 주문해 주세요.")

    # 지불
    def pay(self):
        print()  # 줄 바꾸면서 
        # 합계 금액 출력
        print(f'총 합계 금액은 {self.price_sum}원 입니다.')
        
        # 지불 방법
        pay_way = 0
        while pay_way != 1 and pay_way != 2 :
            pay_way = int(input('현금 결제는 1번, 카드 결제는 2번을 입력해주세요. : '))
            if pay_way == 1:
                print('직원을 호출하겠습니다.')
            elif pay_way == 2:
                print('IC칩 방향에 맞게 카드를 꽂아주세요.')
            else:
                print('다시 결제를 시도해 주세요.')

    # 주문서 출력 
    def table(self):
        print()  # 줄 바꾸면서 
        # 외곽
        outline1 = '⟝' + '-' * 30 + '⟞'
        outline2 = '|' + ' ' * 31 + '|'
        
        print(outline1)
        for i in range(5):
            print(outline2)

        # 주문 상품명 : 해당 금액
        for i in range(len(self.order_menu)):
            print(self.order_menu[i], ' : ', self.order_price[i])

        print('합계 금액 :', self.price_sum)

        # 외곽
        for i in range(5):
            print(outline2)
        print(outline1)

# %%
a = Kiosk()  # 객체 생성 
a.menu_print()  # 메뉴 출력
a.menu_select()  # 주문
a.pay()  # 지불
a.table()  # 주문표 출력
# Out:
# 1 americano  :  2000 원
# 2 latte  :  3000 원
# 3 mocha  :  3000 원
# 4 yuza_tea  :  2500 원
# 5 green_tea  :  2500 원
# 6 choco_latte  :  3000 원
#
# 음료를 번호를 입력하세요 : 1
# HOT 음료는 1을, ICE 음료는 2를 입력하세요 : 2
# ICE americano  :  2000 원
#
# 추가 주문은 음료 번호를, 지불은 0을 누르세요 : 2
# HOT 음료는 1을, ICE 음료는 2를 입력하세요 : 2
# 추가 주문 음료 ICE latte : 3000 원
#  합계 :  5000 원
#
# 추가 주문은 음료 번호를, 지불은 0을 누르세요 : 3
# HOT 음료는 1을, ICE 음료는 2를 입력하세요 : 2
# 추가 주문 음료 ICE mocha : 3000 원
#  합계 :  8000 원
#
# 추가 주문은 음료 번호를, 지불은 0을 누르세요 : 4
# HOT 음료는 1을, ICE 음료는 2를 입력하세요 : 1
# 추가 주문 음료 HOT yuza_tea : 2500 원
#  합계 :  10500 원
#
# 추가 주문은 음료 번호를, 지불은 0을 누르세요 : 5
# HOT 음료는 1을, ICE 음료는 2를 입력하세요 : 2
# 추가 주문 음료 ICE green_tea : 2500 원
#  합계 :  13000 원
#
# 추가 주문은 음료 번호를, 지불은 0을 누르세요 : 6
# HOT 음료는 1을, ICE 음료는 2를 입력하세요 : 1
# 추가 주문 음료 HOT choco_latte : 3000 원
#  합계 :  16000 원
#
# 추가 주문은 음료 번호를, 지불은 0을 누르세요 : 0
# 주문이 완료되었습니다.
# ['ICE americano', 'ICE latte', 'ICE mocha', 'HOT yuza_tea', 'ICE green_tea', 'HOT choco_latte'] [2000, 3000, 3000, 2500, 2500, 3000]
#
# 총 합계 금액은 16000원 입니다.
# 현금 결제는 1번, 카드 결제는 2번을 입력해주세요. : 1
# 직원을 호출하겠습니다.
#
# ⟝------------------------------⟞
# |                               |
# |                               |
# |                               |
# |                               |
# |                               |
# ICE americano  :  2000
# ICE latte  :  3000
# ICE mocha  :  3000
# HOT yuza_tea  :  2500
# ICE green_tea  :  2500
# HOT choco_latte  :  3000
# 합계 금액 : 16000
# |                               |
# |                               |
# |                               |
# |                               |
# |                               |
# ⟝------------------------------⟞

# %% [markdown]
# ### 심화과정

# %%
# order_menu, order_price 리스트로 주문 내역 관리하던 것을
# 클래스 객체로 변환하여 관리하는 방법 고안해보기

# 주문 내역 저장
class Order:
    def __init__(self, menu: str, price: int):
        self.menu = menu
        self.price = price
    
    

class Kiosk:
    def __init__(self):
        self.menu = ['americano', 'latte', 'mocha', 'yuza_tea', 'green_tea', 'choco_latte']
        self.price = [2000, 3000, 3000, 2500, 2500, 3000]

    # 메뉴 출력 메서드
    def menu_print(self):
        for i in range(len(self.menu)):
            print(i + 1, self.menu[i], ' : ', self.price[i], '원')
        print()

    # 주문 메서드
    def menu_select(self):
        self.orders = []  # 주문 + 가격 리스트

        n = 0
        while n < 1 or len(self.menu) < n:
            n = int(input("음료를 번호를 입력하세요 : "))  # 음료 번호 입력

            # 메뉴판에 있는 음료 번호일 때
            if 1 <= n & n <= len(self.menu):
                self.price_sum = self.price[n-1]  # 합계 금액

                # 메뉴판에 없는 번호일 때
            else:  
                print("없는 메뉴입니다. 다시 주문해 주세요.")


        # 음료 온도 물어보기
        t = 0  # 기본값을 넣어주고
        while t != 1 and t != 2:  # 1이나 2를 입력할 때까지 물어보기
            t= int(input("HOT 음료는 1을, ICE 음료는 2를 입력하세요 : "))
            # 문제 2-3의 답을 입력하세요. 
            if t == 1:
                self.temp = 'HOT'
            elif t == 2:
                self.temp = 'ICE'

            else:    
                print("1과 2 중 하나를 입력하세요.\n")

        self.orders.append(Order(self.temp + ' ' + self.menu[n-1], self.price[n-1]))  # 리스트에 추가합니다.
        
        # 문제 2-2의 답을 입력하세요. 
        print(self.temp, self.menu[n-1], ' : ', self.price_sum, '원')  # 온도 속성을 추가한 주문 결과를 출력합니다.

        # 추가 주문 또는 지불
        while n != 0:  # 지불을 선택하기 전까지 반복합니다.
            print()  # 줄 바꾸면서 
            n = int(input("추가 주문은 음료 번호를, 지불은 0을 누르세요 : "))  # 추가 주문 또는 지불
            if n > 0 and n < len(self.menu) + 1: 
                # 추가 음료 온도 
                # 문제 2-4. 추가 음료의 온도를 입력받고, 가격 리스트, 주문 리스트, 합계 금액을 업데이트해보세요.
                t = 0
                while t != 1 and t != 2:
                    t = int(input("HOT 음료는 1을, ICE 음료는 2를 입력하세요 : "))
                    if t == 1:
                        self.temp = "HOT"
                    elif t == 2:
                        self.temp = 'ICE'
                    else :
                        print("1과 2 중 하나를 입력하세요. \n")
                        
                self.price_sum += self.price[n-1]  # 합계 금액
                self.orders.append(Order(self.temp + ' ' + self.menu[n-1], self.price[n-1]))  # 리스트에 추가합니다.

                print('추가 주문 음료', self.temp, self.menu[n-1], ':', self.price[n-1], '원\n', '합계 : ', self.price_sum, '원')
            else :
                if n == 0 :  # 지불을 입력하면
                    print("주문이 완료되었습니다.")
                    print([[x.menu, x.price] for x in self.orders])  # 확인을 위한 리스트를 출력합니다.
                else :  # 없는 번호를 입력할 때
                    print("없는 메뉴입니다. 다시 주문해 주세요.")

    # 지불
    def pay(self):
        print()  # 줄 바꾸면서 
        # 합계 금액 출력
        print(f'총 합계 금액은 {self.price_sum}원 입니다.')
        
        # 지불 방법
        pay_way = 0
        while pay_way != 1 and pay_way != 2 :
            pay_way = int(input('현금 결제는 1번, 카드 결제는 2번을 입력해주세요. : '))
            if pay_way == 1:
                print('직원을 호출하겠습니다.')
            elif pay_way == 2:
                print('IC칩 방향에 맞게 카드를 꽂아주세요.')
            else:
                print('다시 결제를 시도해 주세요.')

    # 주문서 출력 
    def table(self):
        print()  # 줄 바꾸면서 
        # 외곽
        outline1 = '⟝' + '-' * 30 + '⟞'
        outline2 = '|' + ' ' * 31 + '|'
        
        print(outline1)
        for i in range(5):
            print(outline2)

        # 주문 상품명 : 해당 금액            
        for i in self.orders:
            print(i.menu, ' : ', i.price)

        print('합계 금액 :', self.price_sum)

        # 외곽
        for i in range(5):
            print(outline2)
        print(outline1)

# %%
a = Kiosk()  # 객체 생성 
a.menu_print()  # 메뉴 출력
a.menu_select()  # 주문
a.pay()  # 지불
a.table()  # 주문표 출력
# Out:
# 1 americano  :  2000 원
# 2 latte  :  3000 원
# 3 mocha  :  3000 원
# 4 yuza_tea  :  2500 원
# 5 green_tea  :  2500 원
# 6 choco_latte  :  3000 원
#
# 음료를 번호를 입력하세요 : 1
# HOT 음료는 1을, ICE 음료는 2를 입력하세요 : 2
# ICE americano  :  2000 원
#
# 추가 주문은 음료 번호를, 지불은 0을 누르세요 : 2
# HOT 음료는 1을, ICE 음료는 2를 입력하세요 : 2
# 추가 주문 음료 ICE latte : 3000 원
#  합계 :  5000 원
#
# 추가 주문은 음료 번호를, 지불은 0을 누르세요 : 3
# HOT 음료는 1을, ICE 음료는 2를 입력하세요 : 2
# 추가 주문 음료 ICE mocha : 3000 원
#  합계 :  8000 원
#
# 추가 주문은 음료 번호를, 지불은 0을 누르세요 : 0
# 주문이 완료되었습니다.
# [['ICE americano', 2000], ['ICE latte', 3000], ['ICE mocha', 3000]]
#
# 총 합계 금액은 8000원 입니다.
# 현금 결제는 1번, 카드 결제는 2번을 입력해주세요. : 2
# IC칩 방향에 맞게 카드를 꽂아주세요.
#
# ⟝------------------------------⟞
# |                               |
# |                               |
# |                               |
# |                               |
# |                               |
# ICE americano  :  2000
# ICE latte  :  3000
# ICE mocha  :  3000
# 합계 금액 : 8000
# |                               |
# |                               |
# |                               |
# |                               |
# |                               |
# ⟝------------------------------⟞
